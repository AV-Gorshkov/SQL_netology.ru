# %% [markdown]
# <a href="https://colab.research.google.com/github/AV-Gorshkov/SQL_netology.ru/blob/main/PY_Pandas(%D0%BE%D1%81%D0%BD%D0%BE%D0%B2%D1%8B_%D1%87%D0%B0%D1%81%D1%82%D1%8C_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# импорт библиотек
import pandas as pd
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# Задание 1
# Напишите функцию, которая классифицирует фильмы из материалов занятия по правилам:
#
# оценка 2 и ниже — низкий рейтинг;
# оценка 4 и ниже — средний рейтинг;
# оценка 4.5 и 5 — высокий рейтинг.
# Результат классификации запишите в столбец class.

# %%
#  Задание 1

#  получение данных
param = r'/content/drive/My Drive/Нетология/Python_Pandas_Numpy/ДЗ_Дата_сет/'

file_1 = 'movies.csv'
file_2 = 'ratings.csv'

file_movies = pd.read_csv(f'{param}{file_1}', sep = ',')
file_rating = pd.read_csv(f'{param}{file_2}', sep = ',')

def class_movie (value_column):

  if value_column <= 2:
    return "низкий рейтинг"
  elif value_column <= 4:
    return "средний рейтинг"
  else:
    return "высокий рейтинг"

file_rating['class'] = file_rating['rating'].apply(class_movie)

df_rating = file_rating.merge( file_movies, left_on='movieId', right_on='movieId',how='inner')
df_rating[['userId','title','genres','class']].head(10)
# Out:
#    userId             title                                       genres  \
# 0       1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1       5  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2       7  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3      15  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4      17  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 5      18  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 6      19  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 7      21  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 8      27  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 9      31  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#              class
# 0  средний рейтинг
# 1  средний рейтинг
# 2  высокий рейтинг
# 3  средний рейтинг
# 4  высокий рейтинг
# 5  средний рейтинг
# 6  средний рейтинг
# ...

# %% [markdown]
# Задание 2
# Используйте файл keywords.csv.
#
# Нужно написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определённому региону. Т. е. если поисковый запрос содержит название города региона, то в столбце ‘region’ пишется название этого региона. Если поисковый запрос не содержит названия города, то ставим ‘undefined’.
#
# Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:

# %%
#  Задание 2

param = r'/content/drive/My Drive/Нетология/Python_Pandas_Numpy/ДЗ_Дата_сет/'

file_1 = 'keywords.csv'

file_key = pd.read_csv(f'{param}{file_1}', sep = ',')

geo_data = {'Центр': ['москва', 'тула', 'ярославль'],
'Северо-Запад': ['петербург', 'псков', 'мурманск'],
'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
}

def geo (value_column):

  for region, list_city in geo_data.items():
    for city in list_city:

      if city in value_column:
        return region

  return 'undefined'

file_key ['region'] = file_key['keyword'].apply(geo)

file_key[ ~(file_key['region']=='undefined') ].head(20)
# Out:
#                                                 keyword   shows  \
# 127                                        авито москва  979292
# 370                            авито ру санкт петербург  425134
# 564                           погода в санкт петербурге  292489
# 849                                     авито ярославль  209581
# 1063                                фарпост владивосток  176951
# 1236                               банк санкт петербург  174375
# 1259                                             москва  153050
# 1346                                    санкт петербург  144232
# 1396                                    гисметео москва  140279
# 1482                                   госуслуги москва  133061
# 1579                                         авито тула  126168
# 1682                                      погода москва  151701
# 2121  электронный дневник санкт петербургского образ...   94835
# 2153                                        авито псков   98931
# ...

# %% [markdown]
# Задание 3 (бонусное)
#
# Есть мнение, что раньше снимали настоящее кино, не то что сейчас. Ваша задача — проверить это утверждение, используя файлы с рейтингами фильмов из прошлого домашнего занятия: файл movies.csv и ratings.csv из базы. Нужно проверить, верно ли, что с ростом года выпуска фильма его средний рейтинг становится ниже.
#
# Вы не будете затрагивать субьективные факторы выставления этих рейтингов, а пройдётесь по алгоритму:
#
# В переменную years запишите список из всех годов с 1950 по 2010 года.
#
# Напишите функцию production_year, которая каждой строке из названия фильма выставляет год выпуска. Не все названия фильмов содержат год выпуска в одинаковом формате, поэтому используйте алгоритм:
#
# для каждой строки пройдите по всем годам списка years;
# если номер года присутствует в названии фильма, то функция возвращает этот год, как год выпуска;
# если ни один из номеров года списка years не встретился в названии фильма, то возвращается 1900 год.
# Запишите год выпуска фильма по алгоритму пункта 2 в новый столбец ‘year’.
#
# Посчитайте средний рейтинг всех фильмов для каждого значения столбца ‘year’ и отсортируйте результат по убыванию рейтинга.

# %%
#  Задание 3

param = r'/content/drive/My Drive/Нетология/Python_Pandas_Numpy/ДЗ_Дата_сет/'

file_1 = 'movies.csv'
file_2 = 'ratings.csv'

file_movies = pd.read_csv(f'{param}{file_1}', sep = ',')
file_rating = pd.read_csv(f'{param}{file_2}', sep = ',')

file_movies.head(10)
# file_rating.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
years = list( range(1950, 2010) )

def  production_year(value_column):

  for year in years:
    if str(year) in value_column:
      return str(year)

  return '1900'

file_movies['year'] = file_movies['title'].apply(production_year)

file_movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995
# 5                        Action|Crime|Thriller  1995
# 6                               Comedy|Romance  1995
# ...

# %%
agg_fun = {'rating': 'mean'}

df_rating = file_rating.merge( file_movies, left_on='movieId', right_on='movieId',how='inner'). groupby(['year']). agg(agg_fun).round(2)

df_rating.sort_values('rating', ascending=False).head(10)
# Out:
#       rating
# year
# 1957    4.04
# 1954    4.01
# 1962    3.97
# 1952    3.95
# 1974    3.94
# 1964    3.94
# 1972    3.94
# 1967    3.92
# 1975    3.88
# 1958    3.84
